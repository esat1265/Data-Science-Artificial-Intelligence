# %%
# !pip install pycaret

# %%
import pandas as pd

# %%
from pycaret.regression import *

# %%
df=pd.read_csv("kcdata.csv")

# %%
df.head()

# %% [markdown]
# Regression

# %%
setup(data=df,target="price")

# %%
best_model=compare_models()

# %% [markdown]
# Clustering

# %%
df=pd.read_csv("cars.csv")

# %%
from pycaret.clustering import *

# %%
setup(df)

# %%
kmeans=create_model('kmeans',num_clusters=4)

# %%
plot_model(kmeans)

# %%
plot_model(kmeans,feature='Cylinder',label=True)

# %%
plot_model(kmeans,plot="tsne")

# %%
plot_model(kmeans,plot="elbow")

# %%
# PCA -Principle Component Analysis - Dimension Reduction- Boyut Kucultme

# %% [markdown]
# Classification

# %%
from pycaret.classification import *

# %%
df=pd.read_csv("train.csv")

# %%
setup(df,target="Survived")

# %%
compare_models()

# %%
dt=create_model('dt',fold=10)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.9048  0.8910  0.8333  0.9091  0.8696  0.7948  0.7967
# 1       0.8730  0.8574  0.7917  0.8636  0.8261  0.7264  0.7281
# 2       0.6508  0.6378  0.5833  0.5385  0.5600  0.2713  0.2719
# 3       0.8065  0.8105  0.8261  0.7037  0.7600  0.5996  0.6050
# 4       0.8387  0.8224  0.7500  0.8182  0.7826  0.6548  0.6564
# 5       0.8226  0.7939  0.6667  0.8421  0.7442  0.6112  0.6209
# 6       0.8065  0.7807  0.6667  0.8000  0.7273  0.5792  0.5850
# 7       0.8065  0.7884  0.7083  0.7727  0.7391  0.5857  0.5871
# 8       0.8871  0.8695  0.7917  0.9048  0.8444  0.7565  0.7606
# 9       0.7581  0.7259  0.5833  0.7368  0.6512  0.4698  0.4773
# Mean    0.8154  0.7977  0.7201  0.7890  0.7504  0.6049  0.6089
# Std     0.0690  0.0702  0.0886  0.1050  0.0876  0.1438  0.1438
# INFO:logs:create_model_container: 15
# INFO:logs:master_model_container: 15
# INFO:logs:display_container: 3
# ...

# %%
dt=create_model('dt')

# %%
# pycaret.nlp import *    nlp ile de yapilabilir. 
# lda = Latent Drichlet Allocation - Topic modelling- Hangi konuda konusuldugunu bukuyor
# NER = Named Entity Recognition - ozne yuklem vs ayiriyor
# Markov Chain - gecmisteki konusmalarina bakip gelecek konusmalarini tahmin edebilirsiniz

# %%
df=pd.read_csv("PastHires.csv")

# %%
df
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 0                 10         Y                   4                 BS
# 1                  0         N                   0                 BS
# 2                  7         N                   6                 BS
# 3                  2         Y                   1                 MS
# 4                 20         N                   2                PhD
# 5                  0         N                   0                PhD
# 6                  5         Y                   2                 MS
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# ...

# %%
df["Employed?"] = df["Employed?"].map({"Y":1,"N":0})

# %%
df
# Out:
#     Years Experience  Employed?  Previous employers Level of Education  \
# 0                 10          1                   4                 BS
# 1                  0          0                   0                 BS
# 2                  7          0                   6                 BS
# 3                  2          1                   1                 MS
# 4                 20          0                   2                PhD
# 5                  0          0                   0                PhD
# 6                  5          1                   2                 MS
# 7                  3          0                   1                 BS
# 8                 15          1                   5                 BS
# 9                  0          0                   0                 BS
# 10                 1          0                   1                PhD
# 11                 4          1                   1                 BS
# ...

# %%
df = df.replace({"Y":1,"N":0,"BS":0,"MS":1,"PhD":3})

# %%
df
# Out:
#     Years Experience  Employed?  Previous employers  Level of Education  \
# 0                 10          1                   4                   0
# 1                  0          0                   0                   0
# 2                  7          0                   6                   0
# 3                  2          1                   1                   1
# 4                 20          0                   2                   3
# 5                  0          0                   0                   3
# 6                  5          1                   2                   1
# 7                  3          0                   1                   0
# 8                 15          1                   5                   0
# 9                  0          0                   0                   0
# 10                 1          0                   1                   3
# 11                 4          1                   1                   0
# ...

# %%
df.corr()
# Out:
#                     Years Experience  Employed?  Previous employers  \
# Years Experience            1.000000   0.265195            0.644131
# Employed?                   0.265195   1.000000            0.340709
# Previous employers          0.644131   0.340709            1.000000
# Level of Education         -0.020455  -0.403009           -0.383725
# Top-tier school            -0.200427  -0.414758           -0.529534
# Interned                   -0.356917   0.025000           -0.397494
# Hired                      -0.201773   0.527046           -0.166268
#
#                     Level of Education  Top-tier school  Interned     Hired
# Years Experience             -0.020455        -0.200427 -0.356917 -0.201773
# Employed?                    -0.403009        -0.414758  0.025000  0.527046
# Previous employers           -0.383725        -0.529534 -0.397494 -0.166268
# Level of Education            1.000000         0.759777 -0.164867 -0.212404
# ...

# %%
# y=df.Hired
y=df["Hired"]

# %%
x=df.drop("Hired",axis=1)

# %%
x
# Out:
#     Years Experience  Employed?  Previous employers  Level of Education  \
# 0                 10          1                   4                   0
# 1                  0          0                   0                   0
# 2                  7          0                   6                   0
# 3                  2          1                   1                   1
# 4                 20          0                   2                   3
# 5                  0          0                   0                   3
# 6                  5          1                   2                   1
# 7                  3          0                   1                   0
# 8                 15          1                   5                   0
# 9                  0          0                   0                   0
# 10                 1          0                   1                   3
# 11                 4          1                   1                   0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()

# %%
d.fit(x,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
d.predict([[10,1,4,1,0,1]]) # bilgilarini girdik ve ise alinip alinamyacagini gorduk
# Out:
# array([1])

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
x_y=pca.fit_transform(x)

# %%
x_y
# Out:
# array([[ 5.24763982, -1.63033122],
#        [-5.43155582, -0.13342481],
#        [ 2.71872716, -3.45354759],
#        [-3.22702312,  0.02151707],
#        [14.51978384,  3.69952954],
#        [-5.46233599,  1.78575965],
#        [-0.09654845, -0.39730672],
#        [-2.27234051, -0.55747409],
#        [10.34159888, -1.50652228],
#        [-5.38446671, -0.35223301],
#        [-4.24582073,  1.23579211],
#        [-1.27406302, -0.49229282],
#        [-5.43359535,  1.78053417]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.89630908, 0.0696089 ])

# %%
import matplotlib.pyplot as plt

# %%
df_y=pd.DataFrame(x_y)

# %%
df_y
# Out:
#             0         1
# 0    5.247640 -1.630331
# 1   -5.431556 -0.133425
# 2    2.718727 -3.453548
# 3   -3.227023  0.021517
# 4   14.519784  3.699530
# 5   -5.462336  1.785760
# 6   -0.096548 -0.397307
# 7   -2.272341 -0.557474
# 8   10.341599 -1.506522
# 9   -5.384467 -0.352233
# 10  -4.245821  1.235792
# 11  -1.274063 -0.492293
# 12  -5.433595  1.780534

# %%
plt.scatter(df_y.loc[:,0],df_y.loc[:,1])
